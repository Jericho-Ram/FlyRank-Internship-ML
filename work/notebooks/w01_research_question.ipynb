# %% [markdown]
# <a href="https://colab.research.google.com/github/Jericho-Ram/FlyRank-Internship-ML/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jericho-Ram/FlyRank-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# I choose Lane 2 (Refresh/Content Opportunity Scoring) because the evidence already exists and it has clear decision and a clear human on the loop, not just because it's the most built-out option.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision: Which page should the reviewers check first
# Action:The content reviewers who don't have time to review a lot of data, they read sugestion action and final_reason_codes to verify it
# Cost of wrong call:false positive which the problem is visible and being read but no action taken; while the false negative which the problem is invisible and didn't reach the top 50

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
      REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
      REPO_DIR = "flyrank-ml-internship-starter"
      if not os.path.isdir(REPO_DIR):
          subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
      os.chdir(REPO_DIR)
      subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)

if not IN_COLAB and os.getcwd().replace("\\", "/").endswith("work/notebooks"):
      os.chdir("../..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

down = (df["trend_direction"] == "down")
print(f"rows: {len(df)} | unique clients: {df['client_id'].nunique()}")
print(f"declining-label rate: {down.mean()*100:.1f}% ({down.sum()} of {len(df)} rows)")
print("baseline vs. trained-model precision@50 on this data (outputs/model_report.md): 0.240 -> 0.680")
print("Explanation: More than half the dataset is labeled declining, no need to worry about candidates shortage")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# rows: 30000 | unique clients: 32
# declining-label rate: 54.2% (16262 of 30000 rows)
# baseline vs. trained-model precision@50 on this data (outputs/model_report.md): 0.240 -> 0.680
# Explanation: More than half the dataset is labeled declining, no need to worry about candidates shortage

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# What i can claim: this is decision-support for reviewer, not an action
# What i can't claim: the refresh doesn't cause recovery -- experiment is needed, not predicting Google's algorithm, and is_declining_label is a proxy not a ground truth

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
