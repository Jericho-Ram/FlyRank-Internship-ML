# %% [markdown]
# <a href="https://colab.research.google.com/github/Jericho-Ram/FlyRank-Internship-ML/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jericho-Ram/FlyRank-Internship-ML/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# Ranking/scoring, since the output is a sorted queue for 50 top ranked.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# Current target: 'is_declining_label' defined from 'trend_direction'/'trend_pct', computed from the same 90-day period as the features; not predicting a future outcome.
#
# Stronger target (not built here): features from the 90-day window would be used to predict decline over the following, separate 30-day period. This makes it a genuinely predictive target, because the rule is now applied to a future period the features couldn't have seen.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# Precision@50 - of the top 50 pages shown to a reviewer, how many are actually declining. The baseline rule  scores 0.240 while the current model scores 0.680; this gap is the number that count as 'good'.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import os
import sys
import subprocess

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
      REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
      REPO_DIR = "flyrank-ml-internship-starter"
      if not os.path.isdir(REPO_DIR):
          subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
      os.chdir(REPO_DIR)
      subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)

if not IN_COLAB and os.getcwd().replace("\\", "/").endswith("work/notebooks"):
      os.chdir("../..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"

import pandas as pd  # noqa: E402

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("rows:", len(df))
print("unique content_id:", df["content_id"].nunique())
assert df["content_id"].nunique() == len(df), "content_id is not unique — grain assumption is wrong"

df.head(3)
print("Grain: one row one item over its trailing 90-day window, verified with content_id uniqueness check -- no duplicates.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# rows: 30000
# unique content_id: 30000
# Grain: one row one item over its trailing 90-day window, verified with content_id uniqueness check -- no duplicates.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# Rule baseline scores 0.240 on precision@50, while the model scores 0.680 with the same held-out split. The pattern emerges from combining many weak signals together which is the model does but a fixed rule can't.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
